# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/content/job_salaries.csv" , encoding = "windows - 1252") 
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0     2020.0               MI              FT
# 1             1     2020.0               SE              FT
# 2             2     2020.0               SE              FT
# 3             3     2020.0               MI              FT
# 4             4     2020.0               SE              FT
# ..          ...        ...              ...             ...
# 602         602     2022.0               SE              FT
# 603         603     2022.0               SE              FT
# 604         604     2022.0               SE              FT
# 605         605     2022.0               SE              FT
# 606         606     2022.0               MI              FT
#
#                       job_title    salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000.0             EUR        79833.0
# 1    Machine Learning Scientist  260000.0             USD       260000.0
# ...

# %%
# Q1
print(df["job_title"].dtypes)
print (df["salary"].dtypes)
print (df["company_size"].dtypes)
# Out:
# object
# float64
# object

# %%
# Q2
b = df.isnull() # finding the position where is null
b
# Out:
#      Unnamed: 0  work_year  experience_level  employment_type  job_title  \
# 0         False      False             False            False      False
# 1         False      False             False            False      False
# 2         False      False             False            False      False
# 3         False      False             False            False      False
# 4         False      False             False            False      False
# ..          ...        ...               ...              ...        ...
# 602       False      False             False            False      False
# 603       False      False             False            False      False
# 604       False      False             False            False      False
# 605       False      False             False            False      False
# 606       False      False             False            False      False
#
#      salary  salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
# finding the columns names which has null values 
d = df.loc[: ,df.isnull().any()].columns
d
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_size'],
#       dtype='object')

# %%
# viwing the columns Name
c = df.columns
c
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
# replace na with 0
replaceNA = df.fillna(0)
replaceNA
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0     2020.0               MI              FT
# 1             1     2020.0               SE              FT
# 2             2     2020.0               SE              FT
# 3             3     2020.0               MI              FT
# 4             4     2020.0               SE              FT
# ..          ...        ...              ...             ...
# 602         602     2022.0               SE              FT
# 603         603     2022.0               SE              FT
# 604         604     2022.0               SE              FT
# 605         605     2022.0               SE              FT
# 606         606     2022.0               MI              FT
#
#                       job_title    salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000.0             EUR        79833.0
# 1    Machine Learning Scientist  260000.0             USD       260000.0
# ...

# %%
#Q 3
def Noise(Column_Name):
  if df[Column_Name].dtypes == np.float64:
    for i in df[Column_Name]:
      if type(i)==int or type(i)==str:
        df[Column_Name]=df[Column_Name].replace(i, 0)

  if df[Column_Name].dtypes == np.int64:
    for i in df[Column_Name]:
      if type(i)==int or type(i)==str:
        df[Column_Name]=df[Column_Name].replace(i, 0)

  if df[Column_Name].dtypes == "object":
    for i in df[Column_Name]:
      if type(i)==int or type(i)==str:
        df[Column_Name]=df[Column_Name].replace(i, 0)
Noise("salary")
Noise("job_title")
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  job_title  \
# 0             0     2020.0               MI              FT        0.0
# 1             1     2020.0               SE              FT        0.0
# 2             2     2020.0               SE              FT        0.0
# 3             3     2020.0               MI              FT        0.0
# 4             4     2020.0               SE              FT        0.0
# ..          ...        ...              ...             ...        ...
# 602         602     2022.0               SE              FT        0.0
# 603         603     2022.0               SE              FT        0.0
# 604         604     2022.0               SE              FT        0.0
# 605         605     2022.0               SE              FT        0.0
# 606         606     2022.0               MI              FT        0.0
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
# Q 4
from sklearn.preprocessing import OrdinalEncoder
orcode = OrdinalEncoder()

jobsalaries_encode1 = orcode.fit_transform(df[["experience_level"]])[:10]
jobsalaries_encode2 = orcode.fit_transform(df[["company_size"]])[:10]

print("ordial1",jobsalaries_encode1)
print("ordial2",jobsalaries_encode2)
# Out:
# ordial1 [[2.]
#  [3.]
#  [3.]
#  [2.]
#  [3.]
#  [0.]
#  [3.]
#  [2.]
#  [2.]
#  [3.]]
# ordial2 [[ 0.]
#  [ 2.]
#  [ 1.]
#  [ 2.]
#  [nan]
#  [ 0.]
#  [ 2.]
#  [ 0.]
#  [nan]
#  [ 2.]]

# %%
#Q5
b = df.isnull()
b
# Out:
#      Unnamed: 0  work_year  experience_level  employment_type  job_title  \
# 0         False      False             False            False      False
# 1         False      False             False            False      False
# 2         False      False             False            False      False
# 3         False      False             False            False      False
# 4         False      False             False            False      False
# ..          ...        ...               ...              ...        ...
# 602       False      False             False            False      False
# 603       False      False             False            False      False
# 604       False      False             False            False      False
# 605       False      False             False            False      False
# 606       False      False             False            False      False
#
#      salary  salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
import numpy as np

# %%
print(df.loc[:,df.isnull().any()].columns)
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_size'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler as scalar

# %%
#Q 6
x=df.iloc[:,1:]
y=df.iloc[:,0]
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.1, random_state=2021)

x_train, x_val, y_train, y_val = train_test_split(x, y, train_size=0.778, random_state=2021)
print(x_train , "xt")
print(x_test, ' xs')
print(x_val , 'xv')
print(y_val, "yv")
# Out:
#      work_year experience_level employment_type  job_title      salary  \
# 37      2020.0               EN              FT        0.0    250000.0
# 48      2020.0               MI              FT        0.0    105000.0
# 378     2022.0               SE              FT        0.0    208775.0
# 208     2021.0               MI              FL        0.0     20000.0
# 177     2021.0               MI             NaN        0.0  30400000.0
# ..         ...              ...             ...        ...         ...
# 44      2020.0               MI              FT        0.0     88000.0
# 128     2021.0               EN              FT        0.0     20000.0
# 57      2020.0               MI              FT        0.0    118000.0
# 341     2022.0               SE              FT        0.0     93700.0
# 116     2021.0               MI              FT        0.0     50000.0
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...
