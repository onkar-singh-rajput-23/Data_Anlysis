# %%
import numpy as np

from sklearn import linear_model, svm
from sklearn import datasets

from sklearn.model_selection import train_test_split

np.random.seed(5)
# I have uploded all the necessary files

# %% [markdown]
# Part 1

# %%
#Q(1) we have to split the data and normalise it and necessary data processing 
import pandas as pd
ds=pd.read_csv("/content/data_banknote_authentication.txt",names=["columns1","columns2","columns3","columns4","class"])
ds.head()
# Out:
#    columns1  columns2  columns3  columns4  class
# 0   3.62160    8.6661   -2.8073  -0.44699      0
# 1   4.54590    8.1674   -2.4586  -1.46210      0
# 2   3.86600   -2.6383    1.9242   0.10645      0
# 3   3.45660    9.5228   -4.0112  -3.59440      0
# 4   0.32924   -4.4552    4.5718  -0.98880      0

# %%
ds.isnull()
# Out:
#       columns1  columns2  columns3  columns4  class
# 0        False     False     False     False  False
# 1        False     False     False     False  False
# 2        False     False     False     False  False
# 3        False     False     False     False  False
# 4        False     False     False     False  False
# ...        ...       ...       ...       ...    ...
# 1367     False     False     False     False  False
# 1368     False     False     False     False  False
# 1369     False     False     False     False  False
# 1370     False     False     False     False  False
# 1371     False     False     False     False  False
#
# [1372 rows x 5 columns]

# %%
ds.describe()
# Out:
#           columns1     columns2     columns3     columns4        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
ds = ds.fillna(0)# but there is no null values in given data set.

# %%
import numpy as np 
from sklearn import preprocessing

# %%
newds = preprocessing.normalize(ds)

# %%
newds
# Out:
# array([[ 0.36905562,  0.88311049, -0.28607517, -0.04555008,  0.        ],
#        [ 0.4650453 ,  0.83552454, -0.25151463, -0.14957274,  0.        ],
#        [ 0.76378018, -0.52123157,  0.38015153,  0.02103063,  0.        ],
#        ...,
#        [-0.16551018, -0.59396188,  0.77643218, -0.12256041,  0.04413252],
#        [-0.23042003, -0.54200465,  0.80130073, -0.08291035,  0.06465753],
#        [-0.62524782, -0.16186242,  0.66025028,  0.29399119,  0.24597656]])

# %%
x = ds.iloc[:,0:4]
y = ds.iloc[:,4]

# %%
from sklearn.model_selection import train_test_split
X_train, xds3, y_train, yds3 = train_test_split(x, y, test_size = 0.3, random_state=5)

# %%
X_train
# Out:
#       columns1  columns2  columns3  columns4
# 131     5.1302    8.6703  -2.89130  -1.50860
# 1090   -1.4628   -1.5706   2.43570   0.49826
# 757     2.6606    3.1681   1.96190   0.18662
# 86     -1.1313    1.9037   7.53390   1.02200
# 1364   -2.8391   -6.6300  10.48490  -0.42113
# ...        ...       ...       ...       ...
# 73      4.1654   -3.4495   3.64300   1.08790
# 1142   -6.5773    6.8017   0.85483  -7.53440
# 998    -3.0866   -6.6362  10.54050  -0.89182
# 206     5.3063    5.2684  -2.89040  -0.52716
# 867    -6.5084    8.7696   0.23191  -3.93700
#
# [960 rows x 4 columns]

# %%
y_train.head()
# Out:
# 131     0
# 1090    1
# 757     0
# 86      0
# 1364    1
# Name: class, dtype: int64

# %%
X_test, X_predict, y_test, predict = train_test_split(xds3, yds3, test_size = 0.3, random_state=5)

# %%
#Q(2) we have apply perceptron and kfold cross validation 
from sklearn.linear_model import Perceptron
clf = Perceptron()
clf.fit(X_train, y_train)
# Out:
# Perceptron()

# %%
clf.score(X_test, y_test)
# Out:
# 0.9722222222222222

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = 3)

# %%
from sklearn.metrics import accuracy_score
 
k = 5
kf = KFold(n_splits=k, random_state=None)
clf = Perceptron()
acc_score = []
 
for train_index , test_index in kf.split(x):
    X_train , X_test = x.iloc[train_index,:],x.iloc[test_index,:]
    y_train , y_test = y[train_index] , y[test_index]
     
    clf.fit(X_train,y_train)
    pred_values = clf.predict(X_test)
     
    acc = accuracy_score(pred_values , y_test)
    acc_score.append(acc)
acc_score
# Out:
# [0.9890909090909091,
#  0.9927272727272727,
#  0.9927007299270073,
#  0.9708029197080292,
#  0.9963503649635036]

# %%
acc_score.sort()

# %%
acc_score #we got max score
# Out:
# [0.9708029197080292,
#  0.9890909090909091,
#  0.9927007299270073,
#  0.9927272727272727,
#  0.9963503649635036]

# %%
#Q(3) we have apply perceptrin by scratch

from re import X
import numpy as np
class perceptron:
  def _init_(self,learning_rate=0.1,n_iterations=1000):
    self.lr=learning_rate
    self.epochs = n_iterations
    self.weights=None
    self.bias=None
  def fit(self,X,y):
    self.weights=np.zeros(X.shape[1])
    self.bias=0
    for epoch in range(self.epochs):
      for i in range(X.shape[0]):
        y_pred = self.activation_function(np.dot(self.weights,X[i])+self.bias)
        self.weights = self.weights + self.lr*(y[i]-y_pred)*X[i]
        self.bias = self.bias +self.lr*(y[i]-y_pred)
    print(self.weights)
    print(self.bias)
  def activation_function(self,activation):
    if activation >= 0:
      return 1
    else:
      return 0
    
  def predict(self,x):
    y_pred=[]
    for i in range(X.shape[0]):
      y_pred.append(self.activation_function(np.dot(self.weights,X[i])+ self.bias))
    return np.array(y_pred)

# %% [markdown]
# part2

# %%
#Q(1)

X_train, xds3, y_train, yds3 = train_test_split(x, y, test_size = 0.3, random_state=5)

# %%
X_test, X_predict, y_test, y_predict = train_test_split(xds3, yds3, test_size = 0.33, random_state=5)

# %%
svm_clf = svm.SVC(C=5, kernel='rbf')

# %%
svm_clf.fit(X_train, y_train)
# Out:
# SVC(C=5)

# %%
svm_clf.score(X_predict, y_predict)
# Out:
# 1.0
